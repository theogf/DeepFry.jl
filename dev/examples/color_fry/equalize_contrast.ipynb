# %% [markdown]
# # Contrast equalizer

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.equalize_contrast(fabio)
save("assets/equalize_contrast.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.6,0.565,0.569)    …  RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.471,0.349,0.337)     RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.506,0.337,0.302)     RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.471,0.357,0.294)     RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.447,0.361,0.318)     RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.471,0.349,0.337)  …  RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.482,0.345,0.322)     RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.463,0.357,0.29)      RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.455,0.361,0.322)     RGB{N0f8}(0.027,0.078,0.114)
#  RGB{N0f8}(0.455,0.361,0.322)     RGB{N0f8}(0.027,0.078,0.114)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.992,0.871,0.792)     RGB{N0f8}(0.851,0.478,0.353)
#  RGB{N0f8}(0.745,0.733,0.659)     RGB{N0f8}(0.973,0.631,0.604)
#  RGB{N0f8}(0.604,0.565,0.557)     RGB{N0f8}(0.973,0.631,0.592)
#  RGB{N0f8}(0.616,0.565,0.533)  …  RGB{N0f8}(0.973,0.639,0.557)
#  RGB{N0f8}(0.627,0.576,0.443)     RGB{N0f8}(0.976,0.643,0.529)
#  RGB{N0f8}(0.635,0.573,0.431)     RGB{N0f8}(0.976,0.647,0.502)
#  RGB{N0f8}(0.796,0.714,0.647)     RGB{N0f8}(0.976,0.651,0.486)
#  RGB{N0f8}(0.788,0.714,0.647)     RGB{N0f8}(0.98,0.651,0.478)
#  RGB{N0f8}(0.788,0.725,0.584)  …  RGB{N0f8}(0.98,0.651,0.478)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
