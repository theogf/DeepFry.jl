# %% [markdown]
# # Glitch that itch

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.rand_glitch(fabio)
save("assets/rand_glitch.png", img); #hide
img #hide
# Out:
# Corrupt JPEG data: 4839 extraneous bytes before marker 0xd9
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.573,0.494,0.498)  …  RGB{N0f8}(0.125,0.278,0.208)
#  RGB{N0f8}(0.439,0.345,0.337)     RGB{N0f8}(0.125,0.275,0.216)
#  RGB{N0f8}(0.482,0.353,0.318)     RGB{N0f8}(0.122,0.271,0.227)
#  RGB{N0f8}(0.467,0.333,0.294)     RGB{N0f8}(0.122,0.267,0.239)
#  RGB{N0f8}(0.451,0.341,0.298)     RGB{N0f8}(0.122,0.263,0.255)
#  RGB{N0f8}(0.463,0.349,0.318)  …  RGB{N0f8}(0.122,0.259,0.267)
#  RGB{N0f8}(0.471,0.353,0.314)     RGB{N0f8}(0.114,0.251,0.267)
#  RGB{N0f8}(0.455,0.345,0.302)     RGB{N0f8}(0.11,0.247,0.271)
#  RGB{N0f8}(0.439,0.333,0.298)     RGB{N0f8}(0.122,0.259,0.282)
#  RGB{N0f8}(0.435,0.341,0.302)     RGB{N0f8}(0.118,0.255,0.271)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.176,0.31,0.314)      RGB{N0f8}(0.024,0.0,0.09)
#  RGB{N0f8}(0.227,0.365,0.373)     RGB{N0f8}(0.024,0.0,0.098)
#  RGB{N0f8}(0.224,0.373,0.384)     RGB{N0f8}(0.024,0.0,0.09)
#  RGB{N0f8}(0.224,0.373,0.384)  …  RGB{N0f8}(0.024,0.0,0.082)
#  RGB{N0f8}(0.216,0.365,0.376)     RGB{N0f8}(0.024,0.0,0.075)
#  RGB{N0f8}(0.204,0.353,0.365)     RGB{N0f8}(0.024,0.0,0.082)
#  RGB{N0f8}(0.192,0.341,0.353)     RGB{N0f8}(0.024,0.0,0.09)
#  RGB{N0f8}(0.18,0.329,0.341)      RGB{N0f8}(0.024,0.0,0.11)
#  RGB{N0f8}(0.176,0.325,0.337)  …  RGB{N0f8}(0.024,0.0,0.125)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
