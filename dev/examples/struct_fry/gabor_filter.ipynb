# %% [markdown]
# # Who the hell is Gabor

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.gabor_filter(fabio)
save("assets/gabor_filter.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.0,0.0,0.0)        …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.298,0.0,0.145)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.208,0.0,0.0)         RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.216,0.22)        RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.043,0.0,0.0)      …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.063,0.18)        RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.11)          RGB{N0f8}(0.0,0.0,0.0)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.914,1.0,0.655)       RGB{N0f8}(0.004,0.004,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.004,0.0,0.0)
#  RGB{N0f8}(0.627,0.647,0.161)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.004,0.004,0.004)
#  RGB{N0f8}(0.271,0.22,0.0)        RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)        …  RGB{N0f8}(0.0,0.0,0.0)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
