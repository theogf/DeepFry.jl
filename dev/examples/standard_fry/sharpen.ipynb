# %% [markdown]
# # sharpen

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.sharpen(fabio)
save("assets/sharpen.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.427,0.4,0.4)      …  RGB{N0f8}(0.114,0.153,0.18)
#  RGB{N0f8}(0.427,0.4,0.4)         RGB{N0f8}(0.114,0.153,0.18)
#  RGB{N0f8}(0.451,0.447,0.455)     RGB{N0f8}(0.114,0.153,0.18)
#  RGB{N0f8}(0.322,0.216,0.208)     RGB{N0f8}(0.11,0.149,0.176)
#  RGB{N0f8}(0.431,0.271,0.243)     RGB{N0f8}(0.106,0.149,0.176)
#  RGB{N0f8}(0.349,0.267,0.204)  …  RGB{N0f8}(0.102,0.145,0.173)
#  RGB{N0f8}(0.329,0.278,0.239)     RGB{N0f8}(0.098,0.137,0.165)
#  RGB{N0f8}(0.373,0.271,0.275)     RGB{N0f8}(0.102,0.145,0.173)
#  RGB{N0f8}(0.392,0.271,0.263)     RGB{N0f8}(0.106,0.149,0.176)
#  RGB{N0f8}(0.357,0.278,0.208)     RGB{N0f8}(0.114,0.153,0.18)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.741,0.663,0.584)     RGB{N0f8}(0.647,0.353,0.239)
#  RGB{N0f8}(0.702,0.62,0.553)      RGB{N0f8}(0.659,0.369,0.278)
#  RGB{N0f8}(0.749,0.616,0.557)     RGB{N0f8}(0.647,0.361,0.286)
#  RGB{N0f8}(0.455,0.486,0.412)  …  RGB{N0f8}(0.655,0.424,0.325)
#  RGB{N0f8}(0.361,0.325,0.345)     RGB{N0f8}(0.655,0.408,0.314)
#  RGB{N0f8}(0.349,0.306,0.302)     RGB{N0f8}(0.659,0.396,0.31)
#  RGB{N0f8}(0.475,0.439,0.306)     RGB{N0f8}(0.682,0.424,0.349)
#  RGB{N0f8}(0.431,0.384,0.247)     RGB{N0f8}(0.686,0.42,0.349)
#  RGB{N0f8}(0.518,0.443,0.412)  …  RGB{N0f8}(0.71,0.443,0.376)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
