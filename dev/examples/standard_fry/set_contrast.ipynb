# %% [markdown]
# # set_contrast

# %%
using TestImages, ImageShow, DeepFry, FileIO
fabio = testimage("fabio")
img = DeepFry.set_contrast(fabio)
save("assets/set_contrast.png", img); #hide
img #hide
# Out:
# 256×256 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.102,0.094,0.094)  …  RGB{N0f8}(0.027,0.035,0.043)
#  RGB{N0f8}(0.086,0.063,0.059)     RGB{N0f8}(0.027,0.035,0.043)
#  RGB{N0f8}(0.094,0.063,0.055)     RGB{N0f8}(0.027,0.035,0.043)
#  RGB{N0f8}(0.082,0.063,0.051)     RGB{N0f8}(0.027,0.035,0.043)
#  RGB{N0f8}(0.082,0.063,0.055)     RGB{N0f8}(0.024,0.035,0.043)
#  RGB{N0f8}(0.086,0.063,0.063)  …  RGB{N0f8}(0.024,0.035,0.043)
#  RGB{N0f8}(0.09,0.063,0.059)      RGB{N0f8}(0.027,0.035,0.043)
#  RGB{N0f8}(0.082,0.063,0.051)     RGB{N0f8}(0.027,0.035,0.043)
#  RGB{N0f8}(0.078,0.063,0.055)     RGB{N0f8}(0.024,0.035,0.043)
#  RGB{N0f8}(0.082,0.063,0.055)     RGB{N0f8}(0.024,0.035,0.039)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.161,0.137,0.122)     RGB{N0f8}(0.153,0.086,0.063)
#  RGB{N0f8}(0.114,0.114,0.098)     RGB{N0f8}(0.157,0.094,0.09)
#  RGB{N0f8}(0.094,0.086,0.082)     RGB{N0f8}(0.161,0.098,0.09)
#  RGB{N0f8}(0.09,0.078,0.075)   …  RGB{N0f8}(0.161,0.098,0.082)
#  RGB{N0f8}(0.106,0.098,0.071)     RGB{N0f8}(0.165,0.102,0.082)
#  RGB{N0f8}(0.106,0.094,0.071)     RGB{N0f8}(0.165,0.106,0.078)
#  RGB{N0f8}(0.122,0.106,0.094)     RGB{N0f8}(0.169,0.106,0.078)
#  RGB{N0f8}(0.137,0.125,0.114)     RGB{N0f8}(0.173,0.11,0.078)
#  RGB{N0f8}(0.122,0.11,0.086)   …  RGB{N0f8}(0.165,0.102,0.071)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
